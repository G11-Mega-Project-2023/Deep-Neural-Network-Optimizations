# %%
pip install apache-tvm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apache-tvm
#   Downloading apache_tvm-0.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (44.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.8/dist-packages (from apache-tvm) (2.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from apache-tvm) (1.7.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from apache-tvm) (4.4.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from apache-tvm) (5.4.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from apache-tvm) (1.21.6)
# Requirement already satisfied: tornado in /usr/local/lib/python3.8/dist-packages (from apache-tvm) (6.0.4)
# Collecting synr==0.6.0
#   Downloading synr-0.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from apache-tvm) (22.2.0)
# Installing collected packages: synr, apache-tvm
# Successfully installed apache-tvm-0.10.0 synr-0.6.0

# %%
import tvm
# !python -m tvm.driver.tvmc
# Out:
# usage: tvmc [--config CONFIG] [-v] [--version] [-h]
#             {micro,run,tune,compile} ...
#
# TVM compiler driver
#
# optional arguments:
#   --config CONFIG       configuration json file
#   -v, --verbose         increase verbosity
#   --version             print the version and exit
#   -h, --help            show this help message and exit.
#
# commands:
#   {micro,run,tune,compile}
#     micro               select micro context.
#     run                 run a compiled module
#     tune                auto-tune a model
#     compile             compile a model.
#
# TVMC - TVM driver command-line interface

# %%
# !wget https://github.com/onnx/models/raw/b9a54e89508f101a1611cd64f4ef56b9cb62c7cf/vision/classification/resnet/model/resnet50-v2-7.onnx
# Out:
# --2023-02-13 07:37:20--  https://github.com/onnx/models/raw/b9a54e89508f101a1611cd64f4ef56b9cb62c7cf/vision/classification/resnet/model/resnet50-v2-7.onnx
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/onnx/models/b9a54e89508f101a1611cd64f4ef56b9cb62c7cf/vision/classification/resnet/model/resnet50-v2-7.onnx [following]
# --2023-02-13 07:37:20--  https://media.githubusercontent.com/media/onnx/models/b9a54e89508f101a1611cd64f4ef56b9cb62c7cf/vision/classification/resnet/model/resnet50-v2-7.onnx
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102442450 (98M) [application/octet-stream]
# Saving to: ‘resnet50-v2-7.onnx’
#
# resnet50-v2-7.onnx  100%[===================>]  97.70M   431MB/s    in 0.2s
#
# 2023-02-13 07:37:25 (431 MB/s) - ‘resnet50-v2-7.onnx’ saved [102442450/102442450]

# %%
# !pip3 install --user onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting onnx
#   Downloading onnx-1.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 89.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx) (1.21.6)
# Collecting protobuf<4,>=3.20.2
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx) (4.4.0)
# Installing collected packages: protobuf, onnx
#   WARNING: The scripts backend-test-tools, check-model and check-node are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed onnx-1.13.0 protobuf-3.20.3

# %%
# This may take several minutes depending on your machine
# %%shell
tvmc compile \
--target "llvm" \
--input-shapes "data:[1,3,224,224]" \
--output resnet50-v2-7-tvm.tar \
resnet50-v2-7.onnx
# Out:
# One or more operators have not been tuned. Please tune your model for better performance. Use DEBUG logging level to see more details.

# %%
# %%shell
# mkdir model
# tar -xvf resnet50-v2-7-tvm.tar -C model
# ls model
# Out:
# mod.so
# mod.json
# mod.params
# mod.json  mod.params  mod.so

# %%
# !tvmc compile \
--target "llvm" \
--input-shapes "data:[1,3,224,224]" \
--output resnet50-v2-7-tvm.tar \
resnet50-v2-7.onnx
# Out:
# One or more operators have not been tuned. Please tune your model for better performance. Use DEBUG logging level to see more details.

# %%
from tvm.contrib.download import download_testdata
from PIL import Image
import numpy as np

img_url = "https://s3.amazonaws.com/model-server/inputs/kitten.jpg"
img_path = download_testdata(img_url, "imagenet_cat.png", module="data")

# Resize it to 224x224
resized_image = Image.open(img_path).resize((224, 224))
img_data = np.asarray(resized_image).astype("float32")

# ONNX expects NCHW input, so convert the array
img_data = np.transpose(img_data, (2, 0, 1))

# Normalize according to ImageNet
imagenet_mean = np.array([0.485, 0.456, 0.406])
imagenet_stddev = np.array([0.229, 0.224, 0.225])
norm_img_data = np.zeros(img_data.shape).astype("float32")
for i in range(img_data.shape[0]):
      norm_img_data[i, :, :] = (img_data[i, :, :] / 255 - imagenet_mean[i]) / imagenet_stddev[i]

# Add batch dimension
img_data = np.expand_dims(norm_img_data, axis=0)

# Save to .npz (outputs imagenet_cat.npz)
np.savez("imagenet_cat", data=img_data)

# %%
# %%shell
# tvmc run \
# --inputs imagenet_cat.npz \
# --output predictions.npz \
# resnet50-v2-7-tvm.tar
# Out:
# 2023-02-13 07:41:25.998 INFO load_module /tmp/tmp0buo5wj1/mod.so

# %%
import os.path
import numpy as np

from scipy.special import softmax

from tvm.contrib.download import download_testdata

# Download a list of labels
labels_url = "https://s3.amazonaws.com/onnx-model-zoo/synset.txt"
labels_path = download_testdata(labels_url, "synset.txt", module="data")

with open(labels_path, "r") as f:
    labels = [l.rstrip() for l in f]

output_file = "predictions.npz"

# Open the output and read the output tensor
if os.path.exists(output_file):
    with np.load(output_file) as data:
        scores = softmax(data["output_0"])
        scores = np.squeeze(scores)
        ranks = np.argsort(scores)[::-1]

        for rank in ranks[0:5]:
            print("class='%s' with probability=%f" % (labels[rank], scores[rank]))
# Out:
# class='n02123045 tabby, tabby cat' with probability=0.610552
# class='n02123159 tiger cat' with probability=0.367180
# class='n02124075 Egyptian cat' with probability=0.019365
# class='n02129604 tiger, Panthera tigris' with probability=0.001273
# class='n04040759 radiator' with probability=0.000261

# %%
# %%shell
# pip install xgboost
#
# tvmc tune \
# --target "llvm" \
# --output resnet50-v2-7-autotuner_records.json \
# resnet50-v2-7.onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.8/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.21.6)
# /usr/local/lib/python3.8/dist-packages/tvm/target/target.py:272: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    0.00/   0.00 GFLOPS | Progress: (0/40) | 0.00 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    7.27/  10.87 GFLOPS | Progress: (2/40) | 5.38 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:   12.51/  12.51 GFLOPS | Progress: (4/40) | 10.46 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    9.79/  22.47 GFLOPS | Progress: (6/40) | 13.57 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    9.03/  22.55 GFLOPS | Progress: (8/40) | 15.16 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    7.62/  22.55 GFLOPS | Progress: (10/40) | 16.70 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    6.03/  22.55 GFLOPS | Progress: (12/40) | 19.05 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    6.28/  22.55 GFLOPS | Progress: (14/40) | 21.89 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:   17.73/  22.55 GFLOPS | Progress: (16/40) | 24.37 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    3.36/  22.55 GFLOPS | Progress: (18/40) | 28.56 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    5.86/  22.55 GFLOPS | Progress: (20/40) | 30.07 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    3.09/  22.55 GFLOPS | Progress: (22/40) | 32.56 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    9.64/  22.55 GFLOPS | Progress: (24/40) | 34.61 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:   16.15/  23.05 GFLOPS | Progress: (26/40) | 36.14 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    6.08/  23.05 GFLOPS | Progress: (28/40) | 37.75 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:   12.39/  23.05 GFLOPS | Progress: (30/40) | 39.18 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:   22.64/  23.05 GFLOPS | Progress: (32/40) | 44.11 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    3.62/  23.05 GFLOPS | Progress: (34/40) | 46.30 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    6.88/  23.05 GFLOPS | Progress: (36/40) | 49.37 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task  1/25]  Current/Best:    3.92/  23.05 GFLOPS | Progress: (38/40) | 51.67 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task
s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    7.99/   9.97 GFLOPS | Progress: (14/40) | 26.10 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    8.51/   9.97 GFLOPS | Progress: (16/40) | 26.94 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:   10.15/  10.15 GFLOPS | Progress: (18/40) | 27.62 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    8.09/  10.15 GFLOPS | Progress: (20/40) | 28.41 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    1.47/  10.42 GFLOPS | Progress: (22/40) | 38.42 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    7.76/  10.42 GFLOPS | Progress: (24/40) | 41.35 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    3.07/  10.42 GFLOPS | Progress: (26/40) | 51.68 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    3.66/  10.42 GFLOPS | Progress: (28/40) | 56.95 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    8.98/  10.42 GFLOPS | Progress: (30/40) | 57.77 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    1.54/  10.42 GFLOPS | Progress: (32/40) | 59.45 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    7.58/  10.42 GFLOPS | Progress: (34/40) | 66.52 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    1.59/  10.42 GFLOPS | Progress: (36/40) | 67.21 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    7.30/  10.42 GFLOPS | Progress: (38/40) | 69.45 s/usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# [Task 25/25]  Current/Best:    3.66/  10.42 GFLOPS | Progress: (40/40) | 79.77 s Done.

# %%
# %%shell
# tvmc compile \
# --target "llvm" \
# --tuning-records resnet50-v2-7-autotuner_records.json  \
# --output resnet50-v2-7-tvm_autotuned.tar \
# resnet50-v2-7.onnx

# %%
# %%shell
# tvmc run \
# --inputs imagenet_cat.npz \
# --output predictions.npz \
# resnet50-v2-7-tvm_autotuned.tar
# Out:
# 2023-02-13 08:16:25.861 INFO load_module /tmp/tmp3lqmkhxl/mod.so

# %%
import os.path
import numpy as np

from scipy.special import softmax

from tvm.contrib.download import download_testdata

# Download a list of labels
labels_url = "https://s3.amazonaws.com/onnx-model-zoo/synset.txt"
labels_path = download_testdata(labels_url, "synset.txt", module="data")

with open(labels_path, "r") as f:
    labels = [l.rstrip() for l in f]

output_file = "predictions.npz"

# Open the output and read the output tensor
if os.path.exists(output_file):
    with np.load(output_file) as data:
        scores = softmax(data["output_0"])
        scores = np.squeeze(scores)
        ranks = np.argsort(scores)[::-1]

        for rank in ranks[0:5]:
            print("class='%s' with probability=%f" % (labels[rank], scores[rank]))
# Out:
# class='n02123045 tabby, tabby cat' with probability=0.610551
# class='n02123159 tiger cat' with probability=0.367180
# class='n02124075 Egyptian cat' with probability=0.019365
# class='n02129604 tiger, Panthera tigris' with probability=0.001273
# class='n04040759 radiator' with probability=0.000261

# %%
# %%shell
# tvmc run \
# --inputs imagenet_cat.npz \
# --output predictions.npz  \
# --print-time \
# --repeat 100 \
# resnet50-v2-7-tvm_autotuned.tar
# Out:
# 2023-02-13 08:10:15.762 INFO load_module /tmp/tmp0i87ta71/mod.so
# Execution time summary:
#  mean (ms)   median (ms)    max (ms)     min (ms)     std (ms)
#   488.3373     406.3493     866.3652     388.1550     142.3620

# %%
# %%shell
# tvmc run \
# --inputs imagenet_cat.npz \
# --output predictions.npz  \
# --print-time \
# --repeat 100 \
# resnet50-v2-7-tvm.tar
# Out:
# 2023-02-13 08:11:06.574 INFO load_module /tmp/tmp9su13l4a/mod.so
# Execution time summary:
#  mean (ms)   median (ms)    max (ms)     min (ms)     std (ms)
#   591.6365     511.3605    1050.6625     485.9541     169.0853
